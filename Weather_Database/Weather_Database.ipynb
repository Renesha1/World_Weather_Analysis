# %%
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 646

# %%
cities
# Out:
# ['punta arenas',
#  'georgetown',
#  'lompoc',
#  'thompson',
#  'lavrentiya',
#  'lagoa',
#  'mount isa',
#  'kirakira',
#  'grimshaw',
#  'victoria',
#  'east london',
#  'barrow',
#  'albany',
#  'touros',
#  'arraial do cabo',
#  'jinchang',
#  'mataura',
#  'bandarbeyla',
#  'faanui',
#  'chuy',
#  'hambantota',
#  'taolanaro',
#  'taldan',
#  'klaksvik',
#  'longyearbyen',
#  'fortuna',
#  'konya',
#  'hermanus',
#  'toliary',
#  'saint-philippe',
#  'butaritari',
#  'norman wells',
#  'westport',
#  'ushuaia',
#  'nanakuli',
#  'luderitz',
#  'tsihombe',
#  'puerto ayora',
#  'saleaula',
#  'new norfolk',
#  'kita',
#  'rikitea',
#  'balykshi',
#  'azimur',
#  'agde',
#  'kawalu',
#  'tumannyy',
#  'castro',
#  'bell ville',
#  'machiques',
#  'belushya guba',
#  'pacific grove',
#  'lorca',
#  'pisco',
#  'natchitoches',
#  'illoqqortoormiut',
#  'busselton',
#  'atuona',
#  'flinders',
#  'inirida',
#  'mangai',
#  'attawapiskat',
#  'bluff',
#  'khatanga',
#  'ostrovnoy',
#  'vila velha',
#  'xining',
#  'tiznit',
#  'qaanaaq',
#  'cremlingen',
#  'portland',
#  'hithadhoo',
#  'yerbogachen',
#  'astoria',
#  'wuning',
#  'ornskoldsvik',
#  'ostersund',
#  'bethel',
#  'meulaboh',
#  'margate',
#  'ati',
#  'palora',
#  'vaini',
#  'dikson',
#  'aswan',
#  'hobart',
#  'inderborskiy',
#  'darhan',
#  'devaprayag',
#  'upernavik',
#  'salinas',
#  'west wendover',
#  'ramygala',
#  'caravelas',
#  'amderma',
#  'shimanovsk',
#  'port arthur',
#  'les escoumins',
#  'nikolskoye',
#  'san patricio',
#  'saskylakh',
#  'maniitsoq',
#  'ipixuna',
#  'nome',
#  'tabiauea',
#  'yaan',
#  'beyneu',
#  'sentyabrskiy',
#  'cairns',
#  'hilo',
#  'filadelfia',
#  'nishihara',
#  'douglas',
#  'kodiak',
#  'udimskiy',
#  'chokurdakh',
#  'port shepstone',
#  'roma',
#  'kalmunai',
#  'tezu',
#  'labuhan',
#  'kapaa',
#  'sao felix do xingu',
#  'coquimbo',
#  'yellowknife',
#  'mayo',
#  'okha',
#  'vardo',
#  'atikokan',
#  'ilhabela',
#  'kasongo-lunda',
#  'barentsburg',
#  'bredasdorp',
#  'mwense',
#  'fuxin',
#  'marawi',
#  'nanortalik',
#  'kamenskoye',
#  'preobrazheniye',
#  'xinzhi',
#  'chengde',
#  'barbar',
#  'port alfred',
#  'naziya',
#  'jayuya',
#  'luis correia',
#  'maningrida',
#  'ninghai',
#  'tilichiki',
#  'port lincoln',
#  'sao borja',
#  'codrington',
#  'vestmanna',
#  'alofi',
#  'cabo san lucas',
#  'vestmannaeyjar',
#  'pevek',
#  'phan rang',
#  'boundiali',
#  'novo aripuana',
#  'sitka',
#  'yar-sale',
#  'tuktoyaktuk',
#  'pointe michel',
#  'dawlatabad',
#  'bathsheba',
#  'patos',
#  'severo-kurilsk',
#  'iqaluit',
#  'ribeira grande',
#  'locri',
#  'chauk',
#  'jamestown',
#  'troitsko-pechorsk',
#  'lamu',
#  'kadykchan',
#  'naze',
#  'mudyuga',
#  'saqqez',
#  'kaitangata',
#  'havre-saint-pierre',
#  'arlit',
#  'sangmelima',
#  'lebu',
#  'aginskoye',
#  'tiksi',
#  'cape town',
#  'iskateley',
#  'vila',
#  'constitucion',
#  'saldanha',
#  'tasiilaq',
#  'ilulissat',
#  'ballina',
#  'oga',
#  'karamken',
#  'isangel',
#  'uvinza',
#  'tyukalinsk',
#  'abu zabad',
#  'saint-joseph',
#  'casablanca',
#  'calama',
#  'zhenlai',
#  'bahia blanca',
#  'teya',
#  'brokopondo',
#  'paamiut',
#  'baymak',
#  'praia da vitoria',
#  'balikpapan',
#  'carnarvon',
#  'mahebourg',
#  'grand river south east',
#  'luchegorsk',
#  'honningsvag',
#  'kodinsk',
#  'tambovka',
#  'broken hill',
#  'aklavik',
#  'nizhneyansk',
#  'kahului',
#  'barawe',
#  'lahaina',
#  'san vicente',
#  'port-gentil',
#  'easton',
#  'dakar',
#  'marcona',
#  'doctor pedro p. pena',
#  'beringovskiy',
#  'vaitupu',
#  'port blair',
#  'kavieng',
#  'aykhal',
#  'siirt',
#  'dir',
#  'pochutla',
#  'bundaberg',
#  'rocha',
#  'rastolita',
#  'tokur',
#  'ulaanbaatar',
#  'olinda',
#  'hasaki',
#  'eskasem',
#  'bohuslav',
#  'great yarmouth',
#  'aflu',
#  'nouadhibou',
#  'rock springs',
#  'balkanabat',
#  'nuuk',
#  'puerto narino',
#  'nidzica',
#  'doha',
#  'dublin',
#  'baley',
#  'cherskiy',
#  'coihaique',
#  'gamba',
#  'peniche',
#  'laramie',
#  'araouane',
#  'morondava',
#  'otukpo',
#  'namibe',
#  'bowen',
#  'rapid valley',
#  'taltal',
#  'nyurba',
#  'bakel',
#  'sobolevo',
#  'kolosovka',
#  'hirara',
#  'basco',
#  'manhattan',
#  'jalu',
#  'jijiga',
#  'harper',
#  'ponta do sol',
#  'mys shmidta',
#  'road town',
#  'mar del plata',
#  'ancud',
#  'provideniya',
#  'mata',
#  'ulladulla',
#  'salumbar',
#  'takoradi',
#  'hami',
#  'avarua',
#  'vila franca do campo',
#  'agadir',
#  'henties bay',
#  'egvekinot',
#  'beidao',
#  'loncoche',
#  'fare',
#  'segalstad',
#  'scottsbluff',
#  'grindavik',
#  'esperance',
#  'solnechnyy',
#  'muisne',
#  'ahipara',
#  'olafsvik',
#  'matara',
#  'tera',
#  'srednekolymsk',
#  'mirador',
#  'kerrville',
#  'lazaro cardenas',
#  'illapel',
#  'geneva',
#  'albstadt',
#  'saint george',
#  'yauya',
#  'carbonia',
#  'borken',
#  'bolungarvik',
#  'souillac',
#  'hatta',
#  'sete',
#  'bur gabo',
#  'byron bay',
#  'arrecife',
#  'trairi',
#  'batemans bay',
#  'najran',
#  'cayenne',
#  'chaplygin',
#  'ischia',
#  'muroto',
#  'edd',
#  'sibu',
#  'port elizabeth',
#  'baker city',
#  'honiara',
#  'seoul',
#  'cidreira',
#  'inuvik',
#  'mamallapuram',
#  'caronport',
#  'porto velho',
#  'cap-haitien',
#  'saint-augustin',
#  'pangnirtung',
#  'antofagasta',
#  'lorengau',
#  'lesnoy',
#  'palabuhanratu',
#  'fort nelson',
#  'itaituba',
#  'karratha',
#  'imbituba',
#  'bilibino',
#  'kavaratti',
#  'taree',
#  'tuatapere',
#  'pierre',
#  'guerrero negro',
#  'utiroa',
#  'bambous virieux',
#  'payo',
#  'muros',
#  'haines junction',
#  'shubarkuduk',
#  'phan thiet',
#  'el carrizo',
#  'slonim',
#  'limoux',
#  'torbay',
#  'galesong',
#  'umm lajj',
#  'venado tuerto',
#  'sorland',
#  'zhangjiakou',
#  'klyuchi',
#  'bonito',
#  'roberto payan',
#  'rawson',
#  'boulder',
#  'perelyub',
#  'kota tinggi',
#  'dossor',
#  'taoudenni',
#  'los llanos de aridane',
#  'maumere',
#  'mantua',
#  'zeya',
#  'san carlos de bariloche',
#  'gravdal',
#  'urucui',
#  'bengkulu',
#  'lasa',
#  'kegayli',
#  'sao joao da barra',
#  'pamanukan',
#  'nanticoke',
#  'svetlyy',
#  'tazovskiy',
#  'salinopolis',
#  'hisua',
#  'luang prabang',
#  'beloha',
#  'itoman',
#  'coulihaut',
#  'caramay',
#  'urosevac',
#  'jojoima',
#  'korla',
#  'oranjemund',
#  'tigzirt',
#  'grafton',
#  'te anau',
#  'cazaje',
#  'clyde river',
#  'college',
#  'mrirt',
#  'sola',
#  'soe',
#  'skjervoy',
#  'tabuk',
#  'dubbo',
#  'kampene',
#  'ocampo',
#  'verkhoshizhemye',
#  'tibati',
#  'vanimo',
#  'marsa matruh',
#  'narsaq',
#  'karaul',
#  'cockburn town',
#  'hofn',
#  'bocana de paiwas',
#  'qujing',
#  'samusu',
#  'barahona',
#  'mitu',
#  'mareeba',
#  'fairbanks',
#  'kushima',
#  'acarau',
#  'thaton',
#  'nkhotakota',
#  'tigil',
#  'bauchi',
#  'tadine',
#  'hudiksvall',
#  'bayburt',
#  'ondarroa',
#  'high prairie',
#  'gavle',
#  'kamenka',
#  'mattawa',
#  'surt',
#  'leshukonskoye',
#  'kutum',
#  'boende',
#  'anantapur',
#  'loiza',
#  'baruun-urt',
#  'kruisfontein',
#  'yulara',
#  'tukrah',
#  'sao filipe',
#  'santa cruz',
#  'asau',
#  'vao',
#  'sosua',
#  'raudeberg',
#  'nelson',
#  'derzhavinsk',
#  'zolotinka',
#  'hovd',
#  'veraval',
#  'carlyle',
#  'betafo',
#  'broome',
#  'santa luzia',
#  'rudabanya',
#  'midland',
#  'jalalabad',
#  'balkhash',
#  'yabelo',
#  'altukhovo',
#  'yeniseysk',
#  'padang',
#  'alugan',
#  'sao miguel do araguaia',
#  'marsala',
#  'katsuura',
#  'waipawa',
#  'seymchan',
#  'hervey bay',
#  'begoro',
#  'buala',
#  'dingle',
#  'ambovombe',
#  'pasni',
#  'hatillo',
#  'mahon',
#  'vacaria',
#  'ola',
#  'komsomolskiy',
#  'calbuco',
#  'jadu',
#  'beeville',
#  'fraserburgh',
#  'wukari',
#  'sao jose da coroa grande',
#  'villaviciosa',
#  'dehui',
#  'bitkine',
#  'laguna',
#  'manavalakurichi',
#  'bonavista',
#  'quang ngai',
#  'novobirilyussy',
#  'hualmay',
#  'tomatlan',
#  'corinth',
#  'vikulovo',
#  'poltavka',
#  'gold coast',
#  'adeje',
#  'umzimvubu',
#  'shagonar',
#  'salalah',
#  'huejuquilla el alto',
#  'ajdabiya',
#  'mezen',
#  'ciudad guayana',
#  'tura',
#  'cocal',
#  'airai',
#  'dekar',
#  'ksenyevka',
#  'gore',
#  'orocue',
#  'santa maria del oro',
#  'meru',
#  'shimoda',
#  'shenjiamen',
#  'monte alegre',
#  'blagoyevo',
#  'mweka',
#  'gusau',
#  'tartus',
#  'knysna',
#  'mankono',
#  'paracuru',
#  'pervomayskiy',
#  'bafq',
#  'urumqi',
#  'visby',
#  'jutai',
#  'hayden',
#  'kidal',
#  'aripuana',
#  'graham',
#  'yefimovskiy',
#  'sindor',
#  'hamilton',
#  'mandalgovi',
#  'dwarka',
#  'oksfjord',
#  'hwange',
#  'nerchinskiy zavod',
#  'barrhead',
#  'taburi',
#  'ballybofey',
#  'geraldton',
#  'okhotsk',
#  'la ronge',
#  'sioux falls',
#  'poum',
#  'ixtapa',
#  'tessalit',
#  'kamaishi',
#  'sangolqui',
#  'rengasdengklok',
#  'thinadhoo',
#  'chapais',
#  'port hedland',
#  'ossora',
#  'coalinga',
#  'novikovo',
#  'la gaulette',
#  'yumen',
#  'joshimath',
#  'talcahuano',
#  'alotau',
#  'darnah',
#  'bogomila',
#  'erzin',
#  'soyo',
#  'mergui',
#  'torrevieja',
#  'tsimlyansk',
#  'banda aceh',
#  'bilma',
#  'cuamba',
#  'bodden town',
#  'djambala',
#  'floro',
#  'sistranda',
#  'aquiraz',
#  'port hardy',
#  'zhezkazgan',
#  'tocopilla',
#  'ibiapina',
#  'bien hoa',
#  'asfi',
#  'mutsamudu',
#  'samarai',
#  'mimongo',
#  'constantine',
#  'pio ix',
#  'auburn',
#  'dunedin',
#  'talara',
#  'svetlogorsk',
#  'santa rosa',
#  'comodoro rivadavia',
#  'kargasok',
#  'hamadan',
#  'krasnoselkup',
#  'zambezi',
#  'coolum beach',
#  'gambela',
#  'praia',
#  'san rafael',
#  'paita',
#  'puerto colombia',
#  'kushmurun',
#  'tarko-sale',
#  'reconquista',
#  'la reforma',
#  'san quintin',
#  'lolua',
#  'moravsky beroun',
#  'carman',
#  'yinchuan',
#  'katsiveli']

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=da54b026605e8baa9cf03c505824fe6e

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | punta arenas
# Processing Record 2 of Set 13 | georgetown
# Processing Record 3 of Set 13 | lompoc
# Processing Record 4 of Set 13 | thompson
# Processing Record 5 of Set 13 | lavrentiya
# Processing Record 6 of Set 13 | lagoa
# Processing Record 7 of Set 13 | mount isa
# Processing Record 8 of Set 13 | kirakira
# Processing Record 9 of Set 13 | grimshaw
# Processing Record 10 of Set 13 | victoria
# Processing Record 11 of Set 13 | east london
# Processing Record 12 of Set 13 | barrow
# Processing Record 13 of Set 13 | albany
# Processing Record 14 of Set 13 | touros
# Processing Record 15 of Set 13 | arraial do cabo
# Processing Record 16 of Set 13 | jinchang
# Processing Record 17 of Set 13 | mataura
# Processing Record 18 of Set 13 | bandarbeyla
# Processing Record 19 of Set 13 | faanui
# Processing Record 20 of Set 13 | chuy
# Processing Record 21 of Set 13 | hambantota
# Processing Record 22 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 13 | taldan
# Processing Record 24 of Set 13 | klaksvik
# Processing Record 25 of Set 13 | longyearbyen
# Processing Record 26 of Set 13 | fortuna
# Processing Record 27 of Set 13 | konya
# Processing Record 28 of Set 13 | hermanus
# Processing Record 29 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 13 | saint-philippe
# Processing Record 31 of Set 13 | butaritari
# Processing Record 32 of Set 13 | norman wells
# Processing Record 33 of Set 13 | westport
# Processing Record 34 of Set 13 | ushuaia
# Processing Record 35 of Set 13 | nanakuli
# Processing Record 36 of Set 13 | luderitz
# Processing Record 37 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 13 | puerto ayora
# Processing Record 39 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 13 | new norfolk
# Processing Record 41 of Set 13 | kita
# Processing Record 42 of Set 13 | rikitea
# Processing Record 43 of Set 13 | balykshi
# Processing Record 44 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 45 of Set 13 | agde
# Processing Record 46 of Set 13 | kawalu
# Processing Record 47 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 13 | castro
# Processing Record 49 of Set 13 | bell ville
# Processing Record 50 of Set 13 | machiques
# Processing Record 1 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 14 | pacific grove
# Processing Record 3 of Set 14 | lorca
# Processing Record 4 of Set 14 | pisco
# Processing Record 5 of Set 14 | natchitoches
# Processing Record 6 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 14 | busselton
# Processing Record 8 of Set 14 | atuona
# Processing Record 9 of Set 14 | flinders
# Processing Record 10 of Set 14 | inirida
# Processing Record 11 of Set 14 | mangai
# Processing Record 12 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 14 | bluff
# Processing Record 14 of Set 14 | khatanga
# Processing Record 15 of Set 14 | ostrovnoy
# Processing Record 16 of Set 14 | vila velha
# Processing Record 17 of Set 14 | xining
# Processing Record 18 of Set 14 | tiznit
# Processing Record 19 of Set 14 | qaanaaq
# Processing Record 20 of Set 14 | cremlingen
# Processing Record 21 of Set 14 | portland
# Processing Record 22 of Set 14 | hithadhoo
# Processing Record 23 of Set 14 | yerbogachen
# Processing Record 24 of Set 14 | astoria
# Processing Record 25 of Set 14 | wuning
# Processing Record 26 of Set 14 | ornskoldsvik
# Processing Record 27 of Set 14 | ostersund
# Processing Record 28 of Set 14 | bethel
# Processing Record 29 of Set 14 | meulaboh
# Processing Record 30 of Set 14 | margate
# Processing Record 31 of Set 14 | ati
# Processing Record 32 of Set 14 | palora
# Processing Record 33 of Set 14 | vaini
# Processing Record 34 of Set 14 | dikson
# Processing Record 35 of Set 14 | aswan
# Processing Record 36 of Set 14 | hobart
# Processing Record 37 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 14 | darhan
# Processing Record 39 of Set 14 | devaprayag
# Processing Record 40 of Set 14 | upernavik
# Processing Record 41 of Set 14 | salinas
# Processing Record 42 of Set 14 | west wendover
# Processing Record 43 of Set 14 | ramygala
# Processing Record 44 of Set 14 | caravelas
# Processing Record 45 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 14 | shimanovsk
# Processing Record 47 of Set 14 | port arthur
# Processing Record 48 of Set 14 | les escoumins
# Processing Record 49 of Set 14 | nikolskoye
# Processing Record 50 of Set 14 | san patricio
# Processing Record 1 of Set 15 | saskylakh
# Processing Record 2 of Set 15 | maniitsoq
# Processing Record 3 of Set 15 | ipixuna
# Processing Record 4 of Set 15 | nome
# Processing Record 5 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 15 | yaan
# Processing Record 7 of Set 15 | beyneu
# Processing Record 8 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 15 | cairns
# Processing Record 10 of Set 15 | hilo
# Processing Record 11 of Set 15 | filadelfia
# Processing Record 12 of Set 15 | nishihara
# Processing Record 13 of Set 15 | douglas
# Processing Record 14 of Set 15 | kodiak
# Processing Record 15 of Set 15 | udimskiy
# Processing Record 16 of Set 15 | chokurdakh
# Processing Record 17 of Set 15 | port shepstone
# Processing Record 18 of Set 15 | roma
# Processing Record 19 of Set 15 | kalmunai
# Processing Record 20 of Set 15 | tezu
# Processing Record 21 of Set 15 | labuhan
# Processing Record 22 of Set 15 | kapaa
# Processing Record 23 of Set 15 | sao felix do xingu
# Processing Record 24 of Set 15 | coquimbo
# Processing Record 25 of Set 15 | yellowknife
# Processing Record 26 of Set 15 | mayo
# Processing Record 27 of Set 15 | okha
# Processing Record 28 of Set 15 | vardo
# Processing Record 29 of Set 15 | atikokan
# Processing Record 30 of Set 15 | ilhabela
# Processing Record 31 of Set 15 | kasongo-lunda
# Processing Record 32 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 15 | bredasdorp
# Processing Record 34 of Set 15 | mwense
# Processing Record 35 of Set 15 | fuxin
# Processing Record 36 of Set 15 | marawi
# Processing Record 37 of Set 15 | nanortalik
# Processing Record 38 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 15 | preobrazheniye
# Processing Record 40 of Set 15 | xinzhi
# Processing Record 41 of Set 15 | chengde
# Processing Record 42 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 15 | port alfred
# Processing Record 44 of Set 15 | naziya
# Processing Record 45 of Set 15 | jayuya
# Processing Record 46 of Set 15 | luis correia
# Processing Record 47 of Set 15 | maningrida
# Processing Record 48 of Set 15 | ninghai
# Processing Record 49 of Set 15 | tilichiki
# Processing Record 50 of Set 15 | port lincoln
# Processing Record 1 of Set 16 | sao borja
# Processing Record 2 of Set 16 | codrington
# Processing Record 3 of Set 16 | vestmanna
# Processing Record 4 of Set 16 | alofi
# Processing Record 5 of Set 16 | cabo san lucas
# Processing Record 6 of Set 16 | vestmannaeyjar
# Processing Record 7 of Set 16 | pevek
# Processing Record 8 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 16 | boundiali
# Processing Record 10 of Set 16 | novo aripuana
# Processing Record 11 of Set 16 | sitka
# Processing Record 12 of Set 16 | yar-sale
# Processing Record 13 of Set 16 | tuktoyaktuk
# Processing Record 14 of Set 16 | pointe michel
# Processing Record 15 of Set 16 | dawlatabad
# Processing Record 16 of Set 16 | bathsheba
# Processing Record 17 of Set 16 | patos
# Processing Record 18 of Set 16 | severo-kurilsk
# Processing Record 19 of Set 16 | iqaluit
# Processing Record 20 of Set 16 | ribeira grande
# Processing Record 21 of Set 16 | locri
# Processing Record 22 of Set 16 | chauk
# Processing Record 23 of Set 16 | jamestown
# Processing Record 24 of Set 16 | troitsko-pechorsk
# Processing Record 25 of Set 16 | lamu
# Processing Record 26 of Set 16 | kadykchan
# City not found. Skipping...
# Processing Record 27 of Set 16 | naze
# Processing Record 28 of Set 16 | mudyuga
# City not found. Skipping...
# Processing Record 29 of Set 16 | saqqez
# Processing Record 30 of Set 16 | kaitangata
# Processing Record 31 of Set 16 | havre-saint-pierre
# Processing Record 32 of Set 16 | arlit
# Processing Record 33 of Set 16 | sangmelima
# Processing Record 34 of Set 16 | lebu
# Processing Record 35 of Set 16 | aginskoye
# Processing Record 36 of Set 16 | tiksi
# Processing Record 37 of Set 16 | cape town
# Processing Record 38 of Set 16 | iskateley
# Processing Record 39 of Set 16 | vila
# Processing Record 40 of Set 16 | constitucion
# Processing Record 41 of Set 16 | saldanha
# Processing Record 42 of Set 16 | tasiilaq
# Processing Record 43 of Set 16 | ilulissat
# Processing Record 44 of Set 16 | ballina
# Processing Record 45 of Set 16 | oga
# Processing Record 46 of Set 16 | karamken
# City not found. Skipping...
# Processing Record 47 of Set 16 | isangel
# Processing Record 48 of Set 16 | uvinza
# Processing Record 49 of Set 16 | tyukalinsk
# Processing Record 50 of Set 16 | abu zabad
# Processing Record 1 of Set 17 | saint-joseph
# Processing Record 2 of Set 17 | casablanca
# Processing Record 3 of Set 17 | calama
# Processing Record 4 of Set 17 | zhenlai
# Processing Record 5 of Set 17 | bahia blanca
# Processing Record 6 of Set 17 | teya
# Processing Record 7 of Set 17 | brokopondo
# Processing Record 8 of Set 17 | paamiut
# Processing Record 9 of Set 17 | baymak
# Processing Record 10 of Set 17 | praia da vitoria
# Processing Record 11 of Set 17 | balikpapan
# Processing Record 12 of Set 17 | carnarvon
# Processing Record 13 of Set 17 | mahebourg
# Processing Record 14 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 17 | luchegorsk
# Processing Record 16 of Set 17 | honningsvag
# Processing Record 17 of Set 17 | kodinsk
# Processing Record 18 of Set 17 | tambovka
# Processing Record 19 of Set 17 | broken hill
# Processing Record 20 of Set 17 | aklavik
# Processing Record 21 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 17 | kahului
# Processing Record 23 of Set 17 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 17 | lahaina
# Processing Record 25 of Set 17 | san vicente
# Processing Record 26 of Set 17 | port-gentil
# Processing Record 27 of Set 17 | easton
# Processing Record 28 of Set 17 | dakar
# Processing Record 29 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 17 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 17 | beringovskiy
# Processing Record 32 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 17 | port blair
# Processing Record 34 of Set 17 | kavieng
# Processing Record 35 of Set 17 | aykhal
# Processing Record 36 of Set 17 | siirt
# Processing Record 37 of Set 17 | dir
# Processing Record 38 of Set 17 | pochutla
# Processing Record 39 of Set 17 | bundaberg
# Processing Record 40 of Set 17 | rocha
# Processing Record 41 of Set 17 | rastolita
# Processing Record 42 of Set 17 | tokur
# Processing Record 43 of Set 17 | ulaanbaatar
# Processing Record 44 of Set 17 | olinda
# Processing Record 45 of Set 17 | hasaki
# Processing Record 46 of Set 17 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 17 | bohuslav
# Processing Record 48 of Set 17 | great yarmouth
# Processing Record 49 of Set 17 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 17 | nouadhibou
# Processing Record 1 of Set 18 | rock springs
# Processing Record 2 of Set 18 | balkanabat
# Processing Record 3 of Set 18 | nuuk
# Processing Record 4 of Set 18 | puerto narino
# Processing Record 5 of Set 18 | nidzica
# Processing Record 6 of Set 18 | doha
# Processing Record 7 of Set 18 | dublin
# Processing Record 8 of Set 18 | baley
# Processing Record 9 of Set 18 | cherskiy
# Processing Record 10 of Set 18 | coihaique
# Processing Record 11 of Set 18 | gamba
# Processing Record 12 of Set 18 | peniche
# Processing Record 13 of Set 18 | laramie
# Processing Record 14 of Set 18 | araouane
# Processing Record 15 of Set 18 | morondava
# Processing Record 16 of Set 18 | otukpo
# Processing Record 17 of Set 18 | namibe
# Processing Record 18 of Set 18 | bowen
# Processing Record 19 of Set 18 | rapid valley
# Processing Record 20 of Set 18 | taltal
# Processing Record 21 of Set 18 | nyurba
# Processing Record 22 of Set 18 | bakel
# Processing Record 23 of Set 18 | sobolevo
# Processing Record 24 of Set 18 | kolosovka
# Processing Record 25 of Set 18 | hirara
# Processing Record 26 of Set 18 | basco
# Processing Record 27 of Set 18 | manhattan
# Processing Record 28 of Set 18 | jalu
# Processing Record 29 of Set 18 | jijiga
# Processing Record 30 of Set 18 | harper
# Processing Record 31 of Set 18 | ponta do sol
# Processing Record 32 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 18 | road town
# Processing Record 34 of Set 18 | mar del plata
# Processing Record 35 of Set 18 | ancud
# Processing Record 36 of Set 18 | provideniya
# Processing Record 37 of Set 18 | mata
# Processing Record 38 of Set 18 | ulladulla
# Processing Record 39 of Set 18 | salumbar
# Processing Record 40 of Set 18 | takoradi
# Processing Record 41 of Set 18 | hami
# Processing Record 42 of Set 18 | avarua
# Processing Record 43 of Set 18 | vila franca do campo
# Processing Record 44 of Set 18 | agadir
# Processing Record 45 of Set 18 | henties bay
# Processing Record 46 of Set 18 | egvekinot
# Processing Record 47 of Set 18 | beidao
# Processing Record 48 of Set 18 | loncoche
# Processing Record 49 of Set 18 | fare
# Processing Record 50 of Set 18 | segalstad
# City not found. Skipping...
# Processing Record 1 of Set 19 | scottsbluff
# Processing Record 2 of Set 19 | grindavik
# Processing Record 3 of Set 19 | esperance
# Processing Record 4 of Set 19 | solnechnyy
# Processing Record 5 of Set 19 | muisne
# Processing Record 6 of Set 19 | ahipara
# Processing Record 7 of Set 19 | olafsvik
# Processing Record 8 of Set 19 | matara
# Processing Record 9 of Set 19 | tera
# Processing Record 10 of Set 19 | srednekolymsk
# Processing Record 11 of Set 19 | mirador
# Processing Record 12 of Set 19 | kerrville
# Processing Record 13 of Set 19 | lazaro cardenas
# Processing Record 14 of Set 19 | illapel
# Processing Record 15 of Set 19 | geneva
# Processing Record 16 of Set 19 | albstadt
# Processing Record 17 of Set 19 | saint george
# Processing Record 18 of Set 19 | yauya
# Processing Record 19 of Set 19 | carbonia
# Processing Record 20 of Set 19 | borken
# Processing Record 21 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 19 | souillac
# Processing Record 23 of Set 19 | hatta
# Processing Record 24 of Set 19 | sete
# Processing Record 25 of Set 19 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 19 | byron bay
# Processing Record 27 of Set 19 | arrecife
# Processing Record 28 of Set 19 | trairi
# Processing Record 29 of Set 19 | batemans bay
# Processing Record 30 of Set 19 | najran
# Processing Record 31 of Set 19 | cayenne
# Processing Record 32 of Set 19 | chaplygin
# Processing Record 33 of Set 19 | ischia
# Processing Record 34 of Set 19 | muroto
# Processing Record 35 of Set 19 | edd
# Processing Record 36 of Set 19 | sibu
# Processing Record 37 of Set 19 | port elizabeth
# Processing Record 38 of Set 19 | baker city
# Processing Record 39 of Set 19 | honiara
# Processing Record 40 of Set 19 | seoul
# Processing Record 41 of Set 19 | cidreira
# Processing Record 42 of Set 19 | inuvik
# Processing Record 43 of Set 19 | mamallapuram
# Processing Record 44 of Set 19 | caronport
# Processing Record 45 of Set 19 | porto velho
# Processing Record 46 of Set 19 | cap-haitien
# Processing Record 47 of Set 19 | saint-augustin
# Processing Record 48 of Set 19 | pangnirtung
# Processing Record 49 of Set 19 | antofagasta
# Processing Record 50 of Set 19 | lorengau
# Processing Record 1 of Set 20 | lesnoy
# Processing Record 2 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 20 | fort nelson
# Processing Record 4 of Set 20 | itaituba
# Processing Record 5 of Set 20 | karratha
# Processing Record 6 of Set 20 | imbituba
# Processing Record 7 of Set 20 | bilibino
# Processing Record 8 of Set 20 | kavaratti
# Processing Record 9 of Set 20 | taree
# Processing Record 10 of Set 20 | tuatapere
# Processing Record 11 of Set 20 | pierre
# Processing Record 12 of Set 20 | guerrero negro
# Processing Record 13 of Set 20 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 20 | bambous virieux
# Processing Record 15 of Set 20 | payo
# Processing Record 16 of Set 20 | muros
# Processing Record 17 of Set 20 | haines junction
# Processing Record 18 of Set 20 | shubarkuduk
# Processing Record 19 of Set 20 | phan thiet
# Processing Record 20 of Set 20 | el carrizo
# Processing Record 21 of Set 20 | slonim
# Processing Record 22 of Set 20 | limoux
# Processing Record 23 of Set 20 | torbay
# Processing Record 24 of Set 20 | galesong
# Processing Record 25 of Set 20 | umm lajj
# Processing Record 26 of Set 20 | venado tuerto
# Processing Record 27 of Set 20 | sorland
# Processing Record 28 of Set 20 | zhangjiakou
# Processing Record 29 of Set 20 | klyuchi
# Processing Record 30 of Set 20 | bonito
# Processing Record 31 of Set 20 | roberto payan
# City not found. Skipping...
# Processing Record 32 of Set 20 | rawson
# Processing Record 33 of Set 20 | boulder
# Processing Record 34 of Set 20 | perelyub
# Processing Record 35 of Set 20 | kota tinggi
# Processing Record 36 of Set 20 | dossor
# Processing Record 37 of Set 20 | taoudenni
# Processing Record 38 of Set 20 | los llanos de aridane
# Processing Record 39 of Set 20 | maumere
# Processing Record 40 of Set 20 | mantua
# Processing Record 41 of Set 20 | zeya
# Processing Record 42 of Set 20 | san carlos de bariloche
# Processing Record 43 of Set 20 | gravdal
# Processing Record 44 of Set 20 | urucui
# Processing Record 45 of Set 20 | bengkulu
# Processing Record 46 of Set 20 | lasa
# Processing Record 47 of Set 20 | kegayli
# City not found. Skipping...
# Processing Record 48 of Set 20 | sao joao da barra
# Processing Record 49 of Set 20 | pamanukan
# Processing Record 50 of Set 20 | nanticoke
# Processing Record 1 of Set 21 | svetlyy
# Processing Record 2 of Set 21 | tazovskiy
# Processing Record 3 of Set 21 | salinopolis
# Processing Record 4 of Set 21 | hisua
# Processing Record 5 of Set 21 | luang prabang
# Processing Record 6 of Set 21 | beloha
# Processing Record 7 of Set 21 | itoman
# Processing Record 8 of Set 21 | coulihaut
# City not found. Skipping...
# Processing Record 9 of Set 21 | caramay
# Processing Record 10 of Set 21 | urosevac
# City not found. Skipping...
# Processing Record 11 of Set 21 | jojoima
# Processing Record 12 of Set 21 | korla
# Processing Record 13 of Set 21 | oranjemund
# Processing Record 14 of Set 21 | tigzirt
# Processing Record 15 of Set 21 | grafton
# Processing Record 16 of Set 21 | te anau
# Processing Record 17 of Set 21 | cazaje
# City not found. Skipping...
# Processing Record 18 of Set 21 | clyde river
# Processing Record 19 of Set 21 | college
# Processing Record 20 of Set 21 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 21 | sola
# Processing Record 22 of Set 21 | soe
# Processing Record 23 of Set 21 | skjervoy
# Processing Record 24 of Set 21 | tabuk
# Processing Record 25 of Set 21 | dubbo
# Processing Record 26 of Set 21 | kampene
# Processing Record 27 of Set 21 | ocampo
# Processing Record 28 of Set 21 | verkhoshizhemye
# Processing Record 29 of Set 21 | tibati
# Processing Record 30 of Set 21 | vanimo
# Processing Record 31 of Set 21 | marsa matruh
# Processing Record 32 of Set 21 | narsaq
# Processing Record 33 of Set 21 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 21 | cockburn town
# Processing Record 35 of Set 21 | hofn
# Processing Record 36 of Set 21 | bocana de paiwas
# Processing Record 37 of Set 21 | qujing
# Processing Record 38 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 21 | barahona
# Processing Record 40 of Set 21 | mitu
# Processing Record 41 of Set 21 | mareeba
# Processing Record 42 of Set 21 | fairbanks
# Processing Record 43 of Set 21 | kushima
# Processing Record 44 of Set 21 | acarau
# Processing Record 45 of Set 21 | thaton
# Processing Record 46 of Set 21 | nkhotakota
# Processing Record 47 of Set 21 | tigil
# Processing Record 48 of Set 21 | bauchi
# Processing Record 49 of Set 21 | tadine
# Processing Record 50 of Set 21 | hudiksvall
# Processing Record 1 of Set 22 | bayburt
# Processing Record 2 of Set 22 | ondarroa
# Processing Record 3 of Set 22 | high prairie
# Processing Record 4 of Set 22 | gavle
# Processing Record 5 of Set 22 | kamenka
# Processing Record 6 of Set 22 | mattawa
# Processing Record 7 of Set 22 | surt
# Processing Record 8 of Set 22 | leshukonskoye
# Processing Record 9 of Set 22 | kutum
# Processing Record 10 of Set 22 | boende
# Processing Record 11 of Set 22 | anantapur
# Processing Record 12 of Set 22 | loiza
# Processing Record 13 of Set 22 | baruun-urt
# Processing Record 14 of Set 22 | kruisfontein
# Processing Record 15 of Set 22 | yulara
# Processing Record 16 of Set 22 | tukrah
# Processing Record 17 of Set 22 | sao filipe
# Processing Record 18 of Set 22 | santa cruz
# Processing Record 19 of Set 22 | asau
# Processing Record 20 of Set 22 | vao
# Processing Record 21 of Set 22 | sosua
# Processing Record 22 of Set 22 | raudeberg
# Processing Record 23 of Set 22 | nelson
# Processing Record 24 of Set 22 | derzhavinsk
# Processing Record 25 of Set 22 | zolotinka
# City not found. Skipping...
# Processing Record 26 of Set 22 | hovd
# Processing Record 27 of Set 22 | veraval
# Processing Record 28 of Set 22 | carlyle
# Processing Record 29 of Set 22 | betafo
# Processing Record 30 of Set 22 | broome
# Processing Record 31 of Set 22 | santa luzia
# Processing Record 32 of Set 22 | rudabanya
# Processing Record 33 of Set 22 | midland
# Processing Record 34 of Set 22 | jalalabad
# Processing Record 35 of Set 22 | balkhash
# Processing Record 36 of Set 22 | yabelo
# Processing Record 37 of Set 22 | altukhovo
# Processing Record 38 of Set 22 | yeniseysk
# Processing Record 39 of Set 22 | padang
# Processing Record 40 of Set 22 | alugan
# Processing Record 41 of Set 22 | sao miguel do araguaia
# Processing Record 42 of Set 22 | marsala
# Processing Record 43 of Set 22 | katsuura
# Processing Record 44 of Set 22 | waipawa
# Processing Record 45 of Set 22 | seymchan
# Processing Record 46 of Set 22 | hervey bay
# Processing Record 47 of Set 22 | begoro
# Processing Record 48 of Set 22 | buala
# Processing Record 49 of Set 22 | dingle
# Processing Record 50 of Set 22 | ambovombe
# Processing Record 1 of Set 23 | pasni
# Processing Record 2 of Set 23 | hatillo
# Processing Record 3 of Set 23 | mahon
# Processing Record 4 of Set 23 | vacaria
# Processing Record 5 of Set 23 | ola
# Processing Record 6 of Set 23 | komsomolskiy
# Processing Record 7 of Set 23 | calbuco
# Processing Record 8 of Set 23 | jadu
# Processing Record 9 of Set 23 | beeville
# Processing Record 10 of Set 23 | fraserburgh
# Processing Record 11 of Set 23 | wukari
# Processing Record 12 of Set 23 | sao jose da coroa grande
# Processing Record 13 of Set 23 | villaviciosa
# Processing Record 14 of Set 23 | dehui
# Processing Record 15 of Set 23 | bitkine
# Processing Record 16 of Set 23 | laguna
# Processing Record 17 of Set 23 | manavalakurichi
# Processing Record 18 of Set 23 | bonavista
# Processing Record 19 of Set 23 | quang ngai
# Processing Record 20 of Set 23 | novobirilyussy
# Processing Record 21 of Set 23 | hualmay
# Processing Record 22 of Set 23 | tomatlan
# Processing Record 23 of Set 23 | corinth
# Processing Record 24 of Set 23 | vikulovo
# Processing Record 25 of Set 23 | poltavka
# Processing Record 26 of Set 23 | gold coast
# Processing Record 27 of Set 23 | adeje
# Processing Record 28 of Set 23 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 23 | shagonar
# Processing Record 30 of Set 23 | salalah
# Processing Record 31 of Set 23 | huejuquilla el alto
# Processing Record 32 of Set 23 | ajdabiya
# Processing Record 33 of Set 23 | mezen
# Processing Record 34 of Set 23 | ciudad guayana
# Processing Record 35 of Set 23 | tura
# Processing Record 36 of Set 23 | cocal
# Processing Record 37 of Set 23 | airai
# Processing Record 38 of Set 23 | dekar
# Processing Record 39 of Set 23 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 23 | gore
# Processing Record 41 of Set 23 | orocue
# Processing Record 42 of Set 23 | santa maria del oro
# Processing Record 43 of Set 23 | meru
# Processing Record 44 of Set 23 | shimoda
# Processing Record 45 of Set 23 | shenjiamen
# Processing Record 46 of Set 23 | monte alegre
# Processing Record 47 of Set 23 | blagoyevo
# Processing Record 48 of Set 23 | mweka
# Processing Record 49 of Set 23 | gusau
# Processing Record 50 of Set 23 | tartus
# Processing Record 1 of Set 24 | knysna
# Processing Record 2 of Set 24 | mankono
# Processing Record 3 of Set 24 | paracuru
# Processing Record 4 of Set 24 | pervomayskiy
# Processing Record 5 of Set 24 | bafq
# Processing Record 6 of Set 24 | urumqi
# Processing Record 7 of Set 24 | visby
# Processing Record 8 of Set 24 | jutai
# Processing Record 9 of Set 24 | hayden
# Processing Record 10 of Set 24 | kidal
# Processing Record 11 of Set 24 | aripuana
# Processing Record 12 of Set 24 | graham
# Processing Record 13 of Set 24 | yefimovskiy
# City not found. Skipping...
# Processing Record 14 of Set 24 | sindor
# Processing Record 15 of Set 24 | hamilton
# Processing Record 16 of Set 24 | mandalgovi
# Processing Record 17 of Set 24 | dwarka
# Processing Record 18 of Set 24 | oksfjord
# Processing Record 19 of Set 24 | hwange
# Processing Record 20 of Set 24 | nerchinskiy zavod
# Processing Record 21 of Set 24 | barrhead
# Processing Record 22 of Set 24 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 24 | ballybofey
# Processing Record 24 of Set 24 | geraldton
# Processing Record 25 of Set 24 | okhotsk
# Processing Record 26 of Set 24 | la ronge
# Processing Record 27 of Set 24 | sioux falls
# Processing Record 28 of Set 24 | poum
# Processing Record 29 of Set 24 | ixtapa
# Processing Record 30 of Set 24 | tessalit
# Processing Record 31 of Set 24 | kamaishi
# Processing Record 32 of Set 24 | sangolqui
# Processing Record 33 of Set 24 | rengasdengklok
# Processing Record 34 of Set 24 | thinadhoo
# Processing Record 35 of Set 24 | chapais
# Processing Record 36 of Set 24 | port hedland
# Processing Record 37 of Set 24 | ossora
# Processing Record 38 of Set 24 | coalinga
# Processing Record 39 of Set 24 | novikovo
# Processing Record 40 of Set 24 | la gaulette
# City not found. Skipping...
# Processing Record 41 of Set 24 | yumen
# Processing Record 42 of Set 24 | joshimath
# Processing Record 43 of Set 24 | talcahuano
# Processing Record 44 of Set 24 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 24 | darnah
# Processing Record 46 of Set 24 | bogomila
# Processing Record 47 of Set 24 | erzin
# Processing Record 48 of Set 24 | soyo
# Processing Record 49 of Set 24 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 24 | torrevieja
# Processing Record 1 of Set 25 | tsimlyansk
# Processing Record 2 of Set 25 | banda aceh
# Processing Record 3 of Set 25 | bilma
# Processing Record 4 of Set 25 | cuamba
# Processing Record 5 of Set 25 | bodden town
# Processing Record 6 of Set 25 | djambala
# Processing Record 7 of Set 25 | floro
# Processing Record 8 of Set 25 | sistranda
# Processing Record 9 of Set 25 | aquiraz
# Processing Record 10 of Set 25 | port hardy
# Processing Record 11 of Set 25 | zhezkazgan
# Processing Record 12 of Set 25 | tocopilla
# Processing Record 13 of Set 25 | ibiapina
# Processing Record 14 of Set 25 | bien hoa
# Processing Record 15 of Set 25 | asfi
# Processing Record 16 of Set 25 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 25 | samarai
# Processing Record 18 of Set 25 | mimongo
# Processing Record 19 of Set 25 | constantine
# Processing Record 20 of Set 25 | pio ix
# Processing Record 21 of Set 25 | auburn
# Processing Record 22 of Set 25 | dunedin
# Processing Record 23 of Set 25 | talara
# Processing Record 24 of Set 25 | svetlogorsk
# Processing Record 25 of Set 25 | santa rosa
# Processing Record 26 of Set 25 | comodoro rivadavia
# Processing Record 27 of Set 25 | kargasok
# Processing Record 28 of Set 25 | hamadan
# Processing Record 29 of Set 25 | krasnoselkup
# Processing Record 30 of Set 25 | zambezi
# Processing Record 31 of Set 25 | coolum beach
# Processing Record 32 of Set 25 | gambela
# Processing Record 33 of Set 25 | praia
# Processing Record 34 of Set 25 | san rafael
# Processing Record 35 of Set 25 | paita
# Processing Record 36 of Set 25 | puerto colombia
# Processing Record 37 of Set 25 | kushmurun
# Processing Record 38 of Set 25 | tarko-sale
# Processing Record 39 of Set 25 | reconquista
# Processing Record 40 of Set 25 | la reforma
# Processing Record 41 of Set 25 | san quintin
# Processing Record 42 of Set 25 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 25 | moravsky beroun
# Processing Record 44 of Set 25 | carman
# Processing Record 45 of Set 25 | yinchuan
# Processing Record 46 of Set 25 | katsiveli
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     57.20        47          40
# 1    Georgetown   5.4112  100.3354     82.40        83          20
# 2        Lompoc  34.6391 -120.4579     53.60        71         100
# 3      Thompson  55.7435  -97.8558     28.40        54          75
# 4    Lavrentiya  65.5833 -171.0000     20.23        87         100
# 5         Lagoa  39.0500  -27.9833     59.29        79          34
# 6     Mount Isa -20.7333  139.5000     71.60        43          39
# 7      Kirakira -10.4544  161.9205     78.80        84          66
# 8      Grimshaw  56.1834 -117.6027     37.40        41          20
# 9      Victoria  22.2855  114.1577     75.00        93         100
#
#    Wind Speed Current Description Country                 Date
# 0       21.85    scattered clouds      CL  2021-04-25 16:11:40
# 1        4.61          few clouds      MY  2021-04-25 16:11:43
# 2        3.44     overcast clouds      US  2021-04-25 16:08:20
# 3        8.05       broken clouds      CA  2021-04-25 16:11:39
# 4        3.71     overcast clouds      RU  2021-04-25 16:11:46
# 5       14.27    scattered clouds      PT  2021-04-25 16:12:40
# 6        5.75          light rain      AU  2021-04-25 16:14:45
# 7        3.38       broken clouds      SB  2021-04-25 16:12:14
# 8       13.80          few clouds      CA  2021-04-25 16:14:45
# 9        1.01     overcast clouds      HK  2021-04-25 16:08:40

# %%
new_column_order = ["City", "Country", "Date", 'Lat', "Lng", "Max Temp", "Humidity", "Cloudiness", 'Wind Speed','Current Description']
new_column_order

city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Punta Arenas      CL  2021-04-25 16:11:40 -53.1500  -70.9167     57.20
# 1    Georgetown      MY  2021-04-25 16:11:43   5.4112  100.3354     82.40
# 2        Lompoc      US  2021-04-25 16:08:20  34.6391 -120.4579     53.60
# 3      Thompson      CA  2021-04-25 16:11:39  55.7435  -97.8558     28.40
# 4    Lavrentiya      RU  2021-04-25 16:11:46  65.5833 -171.0000     20.23
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        47          40       21.85    scattered clouds
# 1        83          20        4.61          few clouds
# 2        71         100        3.44     overcast clouds
# 3        54          75        8.05       broken clouds
# 4        87         100        3.71     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
